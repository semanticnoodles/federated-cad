# %% [markdown]
# # Creating Collections as Data Using Federated Queries / BNF Query Building (2)
# ## About the Notebook
# This notebook demonstrates how to use [SPARQL](https://www.w3.org/TR/sparql11-query/) to query Linked Open Data repositories. Specifically, it showcases how to perform federated queries by combining data from [Wikidata](https://www.wikidata.org) and the [Bibliothèque nationale de France (BNF)](https://data.bnf.fr), which has published its catalog as Linked Open Data.
#
# [![Launch](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/semanticnoodles/federated-cad/HEAD?filepath=notebooks/01-query-building/LOD-BNF-Federated-Query.ipynb)
#
# <!--🔖 **How to Cite**: [![DOI](https://zenodo.org/badge/DOI_NUMBER.svg)](https://doi.org/DOI_NUMBER) fix once we get the CITATION.cff set up in the GitHub repo-->
#
# ---
#
# ## Getting Started
# First of all, we start by importing the `SPARQLWrapper` library, which is used to interact with SPARQL endpoints.
# Then, the SPARQL endpoint for Wikidata is set up, and JSON is the return format specified for our query.

# %%
# Import necessary libraries
from SPARQLWrapper import SPARQLWrapper, JSON

# Set up the SPARQL endpoint for Wikidata
sparql = SPARQLWrapper("https://query.wikidata.org/sparql")
sparql.setReturnFormat(JSON)

# %% [markdown]
# ## Writing Our First SPARQL Query
#
# In this section, we construct a federated SPARQL query that begins by retrieving the BNF identifier (`P268`) for a specific Wikidata entity, in this case, the author Jorge Juan y Santacilia (`wd:Q2085725`). What makes this query federated is the use of the `SERVICE` keyword, which allows us to access the BNF SPARQL endpoint and combine its data with Wikidata.
#
# Differently from the previous example, we are using [*Dublin Core*](https://www.dublincore.org/specifications/dublin-core/dcmi-terms/) metadata terms to retrieve the bibliographic information; we do so by querying the endpoint to retrieve biblographic expressions (`?expression`) associated to this author.
#
# Following the [*Functional Requirements for Bibliographic Records (FRBR)*](https://repository.ifla.org/items/ffb50f46-46ab-4ec4-8970-b00e2b0d2811), an *expression* is understood as a specific realization of a work (e.g. a particular edition or translation), while a *manifestation* is the physical or digital embodiment of that expression. Although this model underlies [*RDA (Resource Description and Access)*](https://www.cilip.org.uk/members/group_content_view.asp?group=215283&id=776197#:~:text=RDA%3A%20Resource%20Description%20and%20Access%20is%20a%20content%20standard%20providing,and%20cultural%20heritage%20bibliographic%20metadata.), RDA defines its own vocabulary and applies descriptive elements at specific entity levels. Therefore, in this case descriptive metadata for a single work are associated with `?manifestation`, not expression.
#
# As such, for each manifestation, the query attempts to collect additional metadata: title (`?title`), edition (`?edition`), place of publication (`?placeOfPublication`), and year of publication (`?yearOfPublication`). The language (`?langCode`) is then retrieved from the expression, though this may also exist at the manifestation level in some records. Many of these fields are optional and will only be included if present in the data.

# %%
sparql.setQuery(
    """
PREFIX dcterms: <http://purl.org/dc/terms/>
PREFIX rdarelationships: <http://rdvocab.info/RDARelationshipsWEMI/>
PREFIX rdagroup1elements: <http://rdvocab.info/Elements/>

SELECT ?author ?expression ?title ?edition ?placeOfPublication ?yearOfPublication ?langCode WHERE {
wd:Q2085725 wdt:P268 ?id
BIND(uri(concat(concat("http://data.bnf.fr/ark:/12148/cb", ?id),"#about")) as ?author)
SERVICE <http://data.bnf.fr/sparql> {
  # ?expression <http://id.loc.gov/vocabulary/relators/aut> ?author .
  OPTIONAL {?expression dcterms:language ?langCode .}
  OPTIONAL {?manifestation dcterms:publisher ?edition .}
  # ?manifestation rdarelationships:expressionManifested ?expression .
  # ?manifestation dcterms:title ?title .
  # ?manifestation dcterms:date ?yearOfPublication .
  OPTIONAL{ ?manifestation rdagroup1elements:placeOfPublication ?placeOfPublication .}
  }
}
LIMIT 1000 # Check if it's the limit that causes issues
"""
)

# %% [markdown]
# ## Storing the Query Results and Creating a DataFrame
# In this section, we will create a dataframe from the results of our SPARQL query. We will use the `pandas` library to create a dataframe and populate it with the data retrieved from the BNF SPARQL endpoint.
#
# If there are missing values in the data, the code handles them by assigning empty strings (`""`) to the corresponding fields. This ensures that the `data` list contains consistent dictionaries, even when some fields are not available in the SPARQL query results.

# %%
# Preview a limited number of results from the SPARQL query
try:
    ret = sparql.queryAndConvert()

    # Limit the number of results to preview
    preview_limit = 7
    # Check if the results contain any bindings
    if "bindings" not in ret["results"]:
        print("No results found.")
        exit(1)
    count = 0

    # Iterate through the results and print the desired fields
    for r in ret["results"]["bindings"]:
        if count >= preview_limit:
            break

    # Print only the most relevant fields
        print(f"Title: {r['title']['value']}")
        print(f"Author: {r['author']['value']}")
        if "yearOfPublication" in r:
            print(f"Year: {r['yearOfPublication']['value']}")
        if "placeOfPublication" in r:
            print(f"Place: {r['placeOfPublication']['value']}")
        if "expression" in r:
            print(f"Expression: {r['expression']['value']}")
        if "edition" in r:
            print(f"Edition: {r['edition']['value']}")
        if "langCode" in r:
            print(f"Language: {r['langCode']['value']}")

        print("---")
        count += 1

except Exception as e:
    print("Exception:")
    print(e)
# Out:
# Title: Dissertation historique et géographique sur le méridien de démarcation entre les domaines d'Espagne et de Portugal, par don Georges Juan,... et don Antoine de Ulloa,... Traduit de l'espagnol
# Author: http://data.bnf.fr/ark:/12148/cb119974653#about
# Year: 1776
# Place: Paris, A. Boudet
# Expression: http://data.bnf.fr/ark:/12148/cb32292716n#Expression
# Edition: Paris, A. Boudet , 1776. In-8°, 205 p., carte
# Language: http://id.loc.gov/vocabulary/iso639-2/fre
# ---
# Title: Voyage historique de l'Amérique méridionale fait par ordre du roi d'Espagne
# Author: http://data.bnf.fr/ark:/12148/cb119974653#about
# Year: 1752
# Place: Paris
# Expression: http://data.bnf.fr/ark:/12148/cb32292718b#Expression
# Edition: Paris : C.-A. Jombert , 1752
# Language: http://id.loc.gov/vocabulary/iso639-2/fre
# ---
# Title: Relacion historica del viage a la America meridional hecho de orden de S. Mag. para medir algunos grados de meridiano terrestre, y venir por ellos en conocimiento de la verdadera figura, y magnitud de la tierra, con otras varias observaciones astronomicas y phisicas : por don Jorge Juan, comendador de Aliagra, en nel orden de San Juan, socio correspondiente de la real academia de las ciencas de Parìs, y don Antonio de Ulloa, de la real sociedad de Londres : ambos capitanes de fragata de la real armada. Primera parte, tomo primero [-quarto]
# Author: http://data.bnf.fr/ark:/12148/cb119974653#about
# Year: 1748
# Expression: http://data.bnf.fr/ark:/12148/cb31511027v#Expression
# Edition: , 1748
# Language: http://id.loc.gov/vocabulary/iso639-2/spa
# ---
# Title: [Illustrations de Voyage historique de l'Amérique méridionale fait par ordre du Roi d'Espagne par Don George Juan... et par Don Antoine de Ulloa...] : atlas
# Author: http://data.bnf.fr/ark:/12148/cb119974653#about
# Year: 1752
# Place: [S.l.]
# Expression: http://data.bnf.fr/ark:/12148/cb47433920k#Expression
# Edition: [S.l.] : [s.n.] , [1752 ?]
# Language: http://id.loc.gov/vocabulary/iso639-2/fre
# ---
# Title: Voyage historique de l'Amérique méridionale fait par ordre du roi d'Espagne, par don George Juan,... et par don Antoine de Ulloa,... ouvrage... qui contient une histoire des Yncas du Pérou et les observations astronomiques et physiques faites pour déterminer la figure et la grandeur de la terre
# Author: http://data.bnf.fr/ark:/12148/cb119974653#about
# Year: 1752
# Place: Amsterdam. - Leipzig
# Expression: http://data.bnf.fr/ark:/12148/cb31511029j#Expression
# Edition: Amsterdam ; Leipzig : Arkstée et Merkus , 1752
# Language: http://id.loc.gov/vocabulary/iso639-2/fre
# ---
# Title: Dissertation historique et géographique sur le méridien de démarcation entre les domaines d'Espagne et de Portugal, par don Georges Juan,... et don Antoine de Ulloa,... Traduit de l'espagnol
# Author: http://data.bnf.fr/ark:/12148/cb119974653#about
# Year: 1776
# Place: Paris
# Expression: http://data.bnf.fr/ark:/12148/cb31511017j#Expression
# Edition: Paris : A. Boudet , 1776
# Language: http://id.loc.gov/vocabulary/iso639-2/fre
# ---
# Title: Observaciones astronómicas y phísicas, hechas de orden de S. Mag. en los reynos del Perú por D. Jorge Juan,... y D. Antonio de Ulloa,... ambos capitanes de fragata de la R. Armada, de las quales se deduce la figura y magnitud de la tierra, y se aplica a la navegación
# Author: http://data.bnf.fr/ark:/12148/cb119974653#about
# Year: 1748
# Place: Madrid
# Expression: http://data.bnf.fr/ark:/12148/cb315110255#Expression
# Edition: Madrid : J. de Zúñiga , 1748
# Language: http://id.loc.gov/vocabulary/iso639-2/spa
# ---

# %% [markdown]
# ## Storing the Query Results and Creating a DataFrame
# In this section, we will create a dataframe from the results of our SPARQL query. We will use the `pandas` library to create a dataframe and populate it with the data retrieved from the BNF SPARQL endpoint.
#
# If there are missing values in the data, the code handles them by assigning empty strings (`""`) to the corresponding fields. This ensures that the `data` list contains consistent dictionaries, even when some fields are not available in the SPARQL query results.

# %%
# Initialize an empty list to store the processed data
data = []

# Iterate through the results from the SPARQL query
for r in ret["results"]["bindings"]:
    data.append(
        {
            "author": r.get("author", {}).get("value", ""),
            "expression": r.get("expression", {}).get("value", ""),
            "title": r.get("title", {}).get("value", ""),
            "langCode": r.get("langCode", {}).get("value", ""),
            "edition": r.get("edition", {}).get("value", ""),
            "yearOfPublication": r.get("yearOfPublication", {}).get("value", ""),
            "placeOfPublication": r.get("placeOfPublication", {}).get("value", ""),
        }
    )

# Print the first 15 items
data[0:15]
# Out:
# [{'author': 'http://data.bnf.fr/ark:/12148/cb119974653#about',
#   'expression': 'http://data.bnf.fr/ark:/12148/cb32292716n#Expression',
#   'title': "Dissertation historique et géographique sur le méridien de démarcation entre les domaines d'Espagne et de Portugal, par don Georges Juan,... et don Antoine de Ulloa,... Traduit de l'espagnol",
#   'langCode': 'http://id.loc.gov/vocabulary/iso639-2/fre',
#   'edition': 'Paris, A. Boudet , 1776. In-8°, 205 p., carte',
#   'yearOfPublication': '1776',
#   'placeOfPublication': 'Paris, A. Boudet'},
#  {'author': 'http://data.bnf.fr/ark:/12148/cb119974653#about',
#   'expression': 'http://data.bnf.fr/ark:/12148/cb32292718b#Expression',
#   'title': "Voyage historique de l'Amérique méridionale fait par ordre du roi d'Espagne",
#   'langCode': 'http://id.loc.gov/vocabulary/iso639-2/fre',
#   'edition': 'Paris : C.-A. Jombert , 1752',
#   'yearOfPublication': '1752',
#   'placeOfPublication': 'Paris'},
#  {'author': 'http://data.bnf.fr/ark:/12148/cb119974653#about',
#   'expression': 'http://data.bnf.fr/ark:/12148/cb31511027v#Expression',
#   'title': 'Relacion historica del viage a la America meridional hecho de orden de S. Mag. para medir algunos grados de meridiano terrestre, y venir por ellos en conocimiento de la verdadera figura, y magnitud de la tierra, con otras varias observaciones astronomicas y phisicas : por don Jorge Juan, comendador de Aliagra, en nel orden de San Juan, socio correspondiente de la real academia de las ciencas de Parìs, y don Antonio de Ulloa, de la real sociedad de Londres : ambos capitanes de fragata de la real armada. Primera parte, tomo primero [-quarto]',
#   'langCode': 'http://id.loc.gov/vocabulary/iso639-2/spa',
#   'edition': ', 1748',
#   'yearOfPublication': '1748',
#   'placeOfPublication': ''},
#  {'author': 'http://data.bnf.fr/ark:/12148/cb119974653#about',
#   'expression': 'http://data.bnf.fr/ark:/12148/cb47433920k#Expression',
#   'title': "[Illustrations de Voyage historique de l'Amérique méridionale fait par ordre du Roi d'Espagne par Don George Juan... et par Don Antoine de Ulloa...] : atlas",
#   'langCode': 'http://id.loc.gov/vocabulary/iso639-2/fre',
#   'edition': '[S.l.] : [s.n.] , [1752 ?]',
#   'yearOfPublication': '1752',
#   'placeOfPublication': '[S.l.]'},
#  {'author': 'http://data.bnf.fr/ark:/12148/cb119974653#about',
#   'expression': 'http://data.bnf.fr/ark:/12148/cb31511029j#Expression',
#   'title': "Voyage historique de l'Amérique méridionale fait par ordre du roi d'Espagne, par don George Juan,... et par don Antoine de Ulloa,... ouvrage... qui contient une histoire des Yncas du Pérou et les observations astronomiques et physiques faites pour déterminer la figure et la grandeur de la terre",
#   'langCode': 'http://id.loc.gov/vocabulary/iso639-2/fre',
#   'edition': 'Amsterdam ; Leipzig : Arkstée et Merkus , 1752',
#   'yearOfPublication': '1752',
#   'placeOfPublication': 'Amsterdam. - Leipzig'},
#  {'author': 'http://data.bnf.fr/ark:/12148/cb119974653#about',
#   'expression': 'http://data.bnf.fr/ark:/12148/cb31511017j#Expression',
#   'title': "Dissertation historique et géographique sur le méridien de démarcation entre les domaines d'Espagne et de Portugal, par don Georges Juan,... et don Antoine de Ulloa,... Traduit de l'espagnol",
#   'langCode': 'http://id.loc.gov/vocabulary/iso639-2/fre',
#   'edition': 'Paris : A. Boudet , 1776',
#   'yearOfPublication': '1776',
#   'placeOfPublication': 'Paris'},
#  {'author': 'http://data.bnf.fr/ark:/12148/cb119974653#about',
#   'expression': 'http://data.bnf.fr/ark:/12148/cb315110255#Expression',
#   'title': 'Observaciones astronómicas y phísicas, hechas de orden de S. Mag. en los reynos del Perú por D. Jorge Juan,... y D. Antonio de Ulloa,... ambos capitanes de fragata de la R. Armada, de las quales se deduce la figura y magnitud de la tierra, y se aplica a la navegación',
#   'langCode': 'http://id.loc.gov/vocabulary/iso639-2/spa',
#   'edition': 'Madrid : J. de Zúñiga , 1748',
#   'yearOfPublication': '1748',
#   'placeOfPublication': 'Madrid'},
#  {'author': 'http://data.bnf.fr/ark:/12148/cb119974653#about',
#   'expression': 'http://data.bnf.fr/ark:/12148/cb31511024t#Expression',
#   'title': 'Jorge Juan y Antonio de Ulloa. Noticias secretas de América (siglo XVIII)...',
#   'langCode': 'http://id.loc.gov/vocabulary/iso639-2/spa',
#   'edition': 'Madrid : Editorial-América , 1918',
#   'yearOfPublication': '1918',
#   'placeOfPublication': 'Madrid'},
#  {'author': 'http://data.bnf.fr/ark:/12148/cb119974653#about',
#   'expression': 'http://data.bnf.fr/ark:/12148/cb31511015v#Expression',
#   'title': "Description de l'Amérique méridionale d'après Georges Juan, Antonio d'Ulloa, de La Condamine et Frézier",
#   'langCode': 'http://id.loc.gov/vocabulary/iso639-2/fre',
#   'edition': 'Tours : A. Mame , 1845',
#   'yearOfPublication': '1845',
#   'placeOfPublication': 'Tours'},
#  {'author': 'http://data.bnf.fr/ark:/12148/cb119974653#about',
#   'expression': 'http://data.bnf.fr/ark:/12148/cb36663304d#Expression',
#   'title': 'Noticias secretas de América',
#   'langCode': 'http://id.loc.gov/vocabulary/iso639-2/spa',
#   'edition': ': Historia 16 , 1991',
#   'yearOfPublication': '1991',
#   'placeOfPublication': ''},
#  {'author': 'http://data.bnf.fr/ark:/12148/cb119974653#about',
#   'expression': 'http://data.bnf.fr/ark:/12148/cb38495400b#Expression',
#   'title': "[Illustrations de Voyage historique de l'Amérique méridionale fait par ordre du Roi d'Espagne par Don George Juan... et par Don Antoine de Ulloa... qui contient une histoire des Yncas du Pérou, et les observations astronomiques et physiques, faites pour déterminer la figure et la grandeur de la Terre]",
#   'langCode': 'http://id.loc.gov/vocabulary/iso639-2/fre',
#   'edition': 'Paris : Jombert , 1752',
#   'yearOfPublication': '1752',
#   'placeOfPublication': 'Paris'},
#  {'author': 'http://data.bnf.fr/ark:/12148/cb119974653#about',
#   'expression': 'http://data.bnf.fr/ark:/12148/cb438889548#Expression',
#   'title': 'Relacion historica del viage a la america meridional hecho de orden de S. Mag. para medir algunos grados de meridiano terrestre, y venir por ellos en conocimiento de la verdadera figura, y magnitud de la tierra, con otras varias observaciones astronomicas, y phisicas',
#   'langCode': 'http://id.loc.gov/vocabulary/iso639-2/spa',
#   'edition': 'Valladolid : Maxtor , 2013',
#   'yearOfPublication': '2013',
#   'placeOfPublication': 'Valladolid'},
#  {'author': 'http://data.bnf.fr/ark:/12148/cb119974653#about',
#   'expression': 'http://data.bnf.fr/ark:/12148/cb37445645p#Expression',
#   'title': 'Noticias secretas de América',
#   'langCode': 'http://id.loc.gov/vocabulary/iso639-2/spa',
#   'edition': 'Madrid : Istmo , cop. 1988',
#   'yearOfPublication': '1988',
#   'placeOfPublication': 'Madrid'},
#  {'author': 'http://data.bnf.fr/ark:/12148/cb119974653#about',
#   'expression': 'http://data.bnf.fr/ark:/12148/cb300606964#Expression',
#   'title': 'Noticias secretas de América sobre el estado naval, militar y político de los Reynos del Perù y provincias de Quito, costas de Nueva Granada y Chile... por D. Jorge Juan y D. Antonio de Ulloa',
#   'langCode': 'http://id.loc.gov/vocabulary/iso639-2/spa',
#   'edition': 'Londres , 1826',
#   'yearOfPublication': '1826',
#   'placeOfPublication': 'Londres'},
#  {'author': 'http://data.bnf.fr/ark:/12148/cb119974653#about',
#   'expression': 'http://data.bnf.fr/ark:/12148/cb306658451#Expression',
#   'title': 'Examen marítimo teórico prático, ó Tratado de mecánica aplicado á la construcción, conocimiento y manejo de los navíos y demas embarcaciones, por don Jorge Juan,... Edición 2a aumentada con una exposición de los principios del cálculo, notas al texto y adiciones, por don Gabriel Ciscar,... Tomo I...',
#   'langCode': 'http://id.loc.gov/vocabulary/iso639-2/spa',
#   'edition': 'Madrid : en la Impr. real , 1793',
#   'yearOfPublication': '1793',
#   'placeOfPublication': 'Madrid'}]

# %% [markdown]
# To make this code more robust and handling missing data more efficiently, we can use `.get()` and providing default values for optional fields, e.g. "Unknown xyz". This would prevent errors and ensure that the data processing step works even when some fields are not available in the query results.

# %%
# Initialize an empty list to store the processed data
data = []

# Iterate through the results from the SPARQL query
for r in ret["results"]["bindings"]:
    # Use .get() to provide default values for optional fields
    author = r.get("author", {}).get("value", "")
    work = r.get("expression", {}).get("value", "Unknown Work")
    title = r.get("title", {}).get("value", "Unknown Title")
    placeOfPublication = r.get("placeOfPublication", {}).get("value", "Unknown Place")
    yearOfPublication = r.get("yearOfPublication", {}).get("value", "Unknown Year")
    langCode = r.get("langCode", {}).get("value", "Unknown Language")
    edition = r.get("edition", {}).get("value", "Unknown Edition")

    # Append a dictionary containing the extracted data to the list
    data.append(
        {
            "author": author,
            "work": work,
            "title": title,
            "placeOfPublication": placeOfPublication,
            "yearOfPublication": yearOfPublication,
            "langCode": langCode,
            "edition": edition,
        }
    )

# Print the first 15 lines of the dictionary to check the results
data[:15]
# Out:
# [{'author': 'http://data.bnf.fr/ark:/12148/cb119974653#about',
#   'work': 'http://data.bnf.fr/ark:/12148/cb32292716n#Expression',
#   'title': "Dissertation historique et géographique sur le méridien de démarcation entre les domaines d'Espagne et de Portugal, par don Georges Juan,... et don Antoine de Ulloa,... Traduit de l'espagnol",
#   'placeOfPublication': 'Paris, A. Boudet',
#   'yearOfPublication': '1776',
#   'langCode': 'http://id.loc.gov/vocabulary/iso639-2/fre',
#   'edition': 'Paris, A. Boudet , 1776. In-8°, 205 p., carte'},
#  {'author': 'http://data.bnf.fr/ark:/12148/cb119974653#about',
#   'work': 'http://data.bnf.fr/ark:/12148/cb32292718b#Expression',
#   'title': "Voyage historique de l'Amérique méridionale fait par ordre du roi d'Espagne",
#   'placeOfPublication': 'Paris',
#   'yearOfPublication': '1752',
#   'langCode': 'http://id.loc.gov/vocabulary/iso639-2/fre',
#   'edition': 'Paris : C.-A. Jombert , 1752'},
#  {'author': 'http://data.bnf.fr/ark:/12148/cb119974653#about',
#   'work': 'http://data.bnf.fr/ark:/12148/cb31511027v#Expression',
#   'title': 'Relacion historica del viage a la America meridional hecho de orden de S. Mag. para medir algunos grados de meridiano terrestre, y venir por ellos en conocimiento de la verdadera figura, y magnitud de la tierra, con otras varias observaciones astronomicas y phisicas : por don Jorge Juan, comendador de Aliagra, en nel orden de San Juan, socio correspondiente de la real academia de las ciencas de Parìs, y don Antonio de Ulloa, de la real sociedad de Londres : ambos capitanes de fragata de la real armada. Primera parte, tomo primero [-quarto]',
#   'placeOfPublication': 'Unknown Place',
#   'yearOfPublication': '1748',
#   'langCode': 'http://id.loc.gov/vocabulary/iso639-2/spa',
#   'edition': ', 1748'},
#  {'author': 'http://data.bnf.fr/ark:/12148/cb119974653#about',
#   'work': 'http://data.bnf.fr/ark:/12148/cb47433920k#Expression',
#   'title': "[Illustrations de Voyage historique de l'Amérique méridionale fait par ordre du Roi d'Espagne par Don George Juan... et par Don Antoine de Ulloa...] : atlas",
#   'placeOfPublication': '[S.l.]',
#   'yearOfPublication': '1752',
#   'langCode': 'http://id.loc.gov/vocabulary/iso639-2/fre',
#   'edition': '[S.l.] : [s.n.] , [1752 ?]'},
#  {'author': 'http://data.bnf.fr/ark:/12148/cb119974653#about',
#   'work': 'http://data.bnf.fr/ark:/12148/cb31511029j#Expression',
#   'title': "Voyage historique de l'Amérique méridionale fait par ordre du roi d'Espagne, par don George Juan,... et par don Antoine de Ulloa,... ouvrage... qui contient une histoire des Yncas du Pérou et les observations astronomiques et physiques faites pour déterminer la figure et la grandeur de la terre",
#   'placeOfPublication': 'Amsterdam. - Leipzig',
#   'yearOfPublication': '1752',
#   'langCode': 'http://id.loc.gov/vocabulary/iso639-2/fre',
#   'edition': 'Amsterdam ; Leipzig : Arkstée et Merkus , 1752'},
#  {'author': 'http://data.bnf.fr/ark:/12148/cb119974653#about',
#   'work': 'http://data.bnf.fr/ark:/12148/cb31511017j#Expression',
#   'title': "Dissertation historique et géographique sur le méridien de démarcation entre les domaines d'Espagne et de Portugal, par don Georges Juan,... et don Antoine de Ulloa,... Traduit de l'espagnol",
#   'placeOfPublication': 'Paris',
#   'yearOfPublication': '1776',
#   'langCode': 'http://id.loc.gov/vocabulary/iso639-2/fre',
#   'edition': 'Paris : A. Boudet , 1776'},
#  {'author': 'http://data.bnf.fr/ark:/12148/cb119974653#about',
#   'work': 'http://data.bnf.fr/ark:/12148/cb315110255#Expression',
#   'title': 'Observaciones astronómicas y phísicas, hechas de orden de S. Mag. en los reynos del Perú por D. Jorge Juan,... y D. Antonio de Ulloa,... ambos capitanes de fragata de la R. Armada, de las quales se deduce la figura y magnitud de la tierra, y se aplica a la navegación',
#   'placeOfPublication': 'Madrid',
#   'yearOfPublication': '1748',
#   'langCode': 'http://id.loc.gov/vocabulary/iso639-2/spa',
#   'edition': 'Madrid : J. de Zúñiga , 1748'},
#  {'author': 'http://data.bnf.fr/ark:/12148/cb119974653#about',
#   'work': 'http://data.bnf.fr/ark:/12148/cb31511024t#Expression',
#   'title': 'Jorge Juan y Antonio de Ulloa. Noticias secretas de América (siglo XVIII)...',
#   'placeOfPublication': 'Madrid',
#   'yearOfPublication': '1918',
#   'langCode': 'http://id.loc.gov/vocabulary/iso639-2/spa',
#   'edition': 'Madrid : Editorial-América , 1918'},
#  {'author': 'http://data.bnf.fr/ark:/12148/cb119974653#about',
#   'work': 'http://data.bnf.fr/ark:/12148/cb31511015v#Expression',
#   'title': "Description de l'Amérique méridionale d'après Georges Juan, Antonio d'Ulloa, de La Condamine et Frézier",
#   'placeOfPublication': 'Tours',
#   'yearOfPublication': '1845',
#   'langCode': 'http://id.loc.gov/vocabulary/iso639-2/fre',
#   'edition': 'Tours : A. Mame , 1845'},
#  {'author': 'http://data.bnf.fr/ark:/12148/cb119974653#about',
#   'work': 'http://data.bnf.fr/ark:/12148/cb36663304d#Expression',
#   'title': 'Noticias secretas de América',
#   'placeOfPublication': 'Unknown Place',
#   'yearOfPublication': '1991',
#   'langCode': 'http://id.loc.gov/vocabulary/iso639-2/spa',
#   'edition': ': Historia 16 , 1991'},
#  {'author': 'http://data.bnf.fr/ark:/12148/cb119974653#about',
#   'work': 'http://data.bnf.fr/ark:/12148/cb38495400b#Expression',
#   'title': "[Illustrations de Voyage historique de l'Amérique méridionale fait par ordre du Roi d'Espagne par Don George Juan... et par Don Antoine de Ulloa... qui contient une histoire des Yncas du Pérou, et les observations astronomiques et physiques, faites pour déterminer la figure et la grandeur de la Terre]",
#   'placeOfPublication': 'Paris',
#   'yearOfPublication': '1752',
#   'langCode': 'http://id.loc.gov/vocabulary/iso639-2/fre',
#   'edition': 'Paris : Jombert , 1752'},
#  {'author': 'http://data.bnf.fr/ark:/12148/cb119974653#about',
#   'work': 'http://data.bnf.fr/ark:/12148/cb438889548#Expression',
#   'title': 'Relacion historica del viage a la america meridional hecho de orden de S. Mag. para medir algunos grados de meridiano terrestre, y venir por ellos en conocimiento de la verdadera figura, y magnitud de la tierra, con otras varias observaciones astronomicas, y phisicas',
#   'placeOfPublication': 'Valladolid',
#   'yearOfPublication': '2013',
#   'langCode': 'http://id.loc.gov/vocabulary/iso639-2/spa',
#   'edition': 'Valladolid : Maxtor , 2013'},
#  {'author': 'http://data.bnf.fr/ark:/12148/cb119974653#about',
#   'work': 'http://data.bnf.fr/ark:/12148/cb37445645p#Expression',
#   'title': 'Noticias secretas de América',
#   'placeOfPublication': 'Madrid',
#   'yearOfPublication': '1988',
#   'langCode': 'http://id.loc.gov/vocabulary/iso639-2/spa',
#   'edition': 'Madrid : Istmo , cop. 1988'},
#  {'author': 'http://data.bnf.fr/ark:/12148/cb119974653#about',
#   'work': 'http://data.bnf.fr/ark:/12148/cb300606964#Expression',
#   'title': 'Noticias secretas de América sobre el estado naval, militar y político de los Reynos del Perù y provincias de Quito, costas de Nueva Granada y Chile... por D. Jorge Juan y D. Antonio de Ulloa',
#   'placeOfPublication': 'Londres',
#   'yearOfPublication': '1826',
#   'langCode': 'http://id.loc.gov/vocabulary/iso639-2/spa',
#   'edition': 'Londres , 1826'},
#  {'author': 'http://data.bnf.fr/ark:/12148/cb119974653#about',
#   'work': 'http://data.bnf.fr/ark:/12148/cb306658451#Expression',
#   'title': 'Examen marítimo teórico prático, ó Tratado de mecánica aplicado á la construcción, conocimiento y manejo de los navíos y demas embarcaciones, por don Jorge Juan,... Edición 2a aumentada con una exposición de los principios del cálculo, notas al texto y adiciones, por don Gabriel Ciscar,... Tomo I...',
#   'placeOfPublication': 'Madrid',
#   'yearOfPublication': '1793',
#   'langCode': 'http://id.loc.gov/vocabulary/iso639-2/spa',
#   'edition': 'Madrid : en la Impr. real , 1793'}]

# %% [markdown]
# Now  let's convert our dictionary into a pandas DataFrame. We will use the `pd.DataFrame()` function to create a DataFrame from the list of dictionaries. Each dictionary in the list will represent a row in the DataFrame, and the keys of the dictionaries will become the column names.

# %%
# Load required libraries
import pandas as pd

# Create a DataFrame from the list of dictionaries
df = pd.DataFrame(data)

# Preview the first 10 rows
df.head(10)
# Out:
#                                             author  \
# 0  http://data.bnf.fr/ark:/12148/cb119974653#about
# 1  http://data.bnf.fr/ark:/12148/cb119974653#about
# 2  http://data.bnf.fr/ark:/12148/cb119974653#about
# 3  http://data.bnf.fr/ark:/12148/cb119974653#about
# 4  http://data.bnf.fr/ark:/12148/cb119974653#about
# 5  http://data.bnf.fr/ark:/12148/cb119974653#about
# 6  http://data.bnf.fr/ark:/12148/cb119974653#about
# 7  http://data.bnf.fr/ark:/12148/cb119974653#about
# 8  http://data.bnf.fr/ark:/12148/cb119974653#about
# 9  http://data.bnf.fr/ark:/12148/cb119974653#about
#
#                                                 work  \
# 0  http://data.bnf.fr/ark:/12148/cb32292716n#Expr...
# 1  http://data.bnf.fr/ark:/12148/cb32292718b#Expr...
# 2  http://data.bnf.fr/ark:/12148/cb31511027v#Expr...
# 3  http://data.bnf.fr/ark:/12148/cb47433920k#Expr...
# 4  http://data.bnf.fr/ark:/12148/cb31511029j#Expr...
# 5  http://data.bnf.fr/ark:/12148/cb31511017j#Expr...
# 6  http://data.bnf.fr/ark:/12148/cb315110255#Expr...
# 7  http://data.bnf.fr/ark:/12148/cb31511024t#Expr...
# 8  http://data.bnf.fr/ark:/12148/cb31511015v#Expr...
# 9  http://data.bnf.fr/ark:/12148/cb36663304d#Expr...
#
#                                                title    placeOfPublication  \
# 0  Dissertation historique et géographique sur le...      Paris, A. Boudet
# 1  Voyage historique de l'Amérique méridionale fa...                 Paris
# 2  Relacion historica del viage a la America meri...         Unknown Place
# 3  [Illustrations de Voyage historique de l'Améri...                [S.l.]
# 4  Voyage historique de l'Amérique méridionale fa...  Amsterdam. - Leipzig
# 5  Dissertation historique et géographique sur le...                 Paris
# 6  Observaciones astronómicas y phísicas, hechas ...                Madrid
# 7  Jorge Juan y Antonio de Ulloa. Noticias secret...                Madrid
# 8  Description de l'Amérique méridionale d'après ...                 Tours
# 9                       Noticias secretas de América         Unknown Place
#
#   yearOfPublication                                   langCode  \
# 0              1776  http://id.loc.gov/vocabulary/iso639-2/fre
# 1              1752  http://id.loc.gov/vocabulary/iso639-2/fre
# 2              1748  http://id.loc.gov/vocabulary/iso639-2/spa
# 3              1752  http://id.loc.gov/vocabulary/iso639-2/fre
# 4              1752  http://id.loc.gov/vocabulary/iso639-2/fre
# 5              1776  http://id.loc.gov/vocabulary/iso639-2/fre
# 6              1748  http://id.loc.gov/vocabulary/iso639-2/spa
# 7              1918  http://id.loc.gov/vocabulary/iso639-2/spa
# 8              1845  http://id.loc.gov/vocabulary/iso639-2/fre
# 9              1991  http://id.loc.gov/vocabulary/iso639-2/spa
#
#                                           edition
# 0   Paris, A. Boudet , 1776. In-8°, 205 p., carte
# 1                    Paris : C.-A. Jombert , 1752
# 2                                          , 1748
# 3                      [S.l.] : [s.n.] , [1752 ?]
# 4  Amsterdam ; Leipzig : Arkstée et Merkus , 1752
# 5                        Paris : A. Boudet , 1776
# 6                    Madrid : J. de Zúñiga , 1748
# 7               Madrid : Editorial-América , 1918
# 8                          Tours : A. Mame , 1845
# 9                            : Historia 16 , 1991

# %%
# Some basic statistics about the DataFrame
df.describe()
# Out:
#                                                  author  \
# count                                                32
# unique                                                1
# top     http://data.bnf.fr/ark:/12148/cb119974653#about
# freq                                                 32
#
#                                                      work  \
# count                                                  32
# unique                                                 32
# top     http://data.bnf.fr/ark:/12148/cb32292716n#Expr...
# freq                                                    1
#
#                                                     title placeOfPublication  \
# count                                                  32                 32
# unique                                                 29                 14
# top     Dissertation historique et géographique sur le...             Madrid
# freq                                                    2                  9
#
#        yearOfPublication                                   langCode  \
# count                 32                                         32
# unique                18                                          5
# top                 1744  http://id.loc.gov/vocabulary/iso639-2/spa
# freq                   6                                         18
#
#                          edition
# count                         32
# unique                        27
# top     [S.l.] : [s.n.] , [1744]
# freq                           4

# %%
# Checking extant data types
df.dtypes
# Out:
# author                object
# work                  object
# title                 object
# placeOfPublication    object
# yearOfPublication     object
# langCode              object
# edition               object
# dtype: object

# %%
# Sort the DataFrame by yearOfPublication
sorted_df = df.sort_values(by="yearOfPublication")

# Preview the first 10 rows
sorted_df.head(10)
# Out:
#                                              author  \
# 27  http://data.bnf.fr/ark:/12148/cb119974653#about
# 24  http://data.bnf.fr/ark:/12148/cb119974653#about
# 25  http://data.bnf.fr/ark:/12148/cb119974653#about
# 26  http://data.bnf.fr/ark:/12148/cb119974653#about
# 28  http://data.bnf.fr/ark:/12148/cb119974653#about
# 29  http://data.bnf.fr/ark:/12148/cb119974653#about
# 31  http://data.bnf.fr/ark:/12148/cb119974653#about
# 2   http://data.bnf.fr/ark:/12148/cb119974653#about
# 6   http://data.bnf.fr/ark:/12148/cb119974653#about
# 18  http://data.bnf.fr/ark:/12148/cb119974653#about
#
#                                                  work  \
# 27  http://data.bnf.fr/ark:/12148/cb40758685h#Expr...
# 24  http://data.bnf.fr/ark:/12148/cb40714961j#Expr...
# 25  http://data.bnf.fr/ark:/12148/cb40756914b#Expr...
# 26  http://data.bnf.fr/ark:/12148/cb40733276t#Expr...
# 28  http://data.bnf.fr/ark:/12148/cb407586845#Expr...
# 29  http://data.bnf.fr/ark:/12148/cb40755700v#Expr...
# 31  http://data.bnf.fr/ark:/12148/cb459969115#Expr...
# 2   http://data.bnf.fr/ark:/12148/cb31511027v#Expr...
# 6   http://data.bnf.fr/ark:/12148/cb315110255#Expr...
# 18  http://data.bnf.fr/ark:/12148/cb30665853n#Expr...
#
#                                                 title placeOfPublication  \
# 27  Plan sénographique (sic) de la cité des rois o...             [S.l.]
# 24  Carta de la meridiana medida en el reyno de Qu...            Matriti
# 25  Grundrifs von der Conceptions-bay... in Jahre ...             [S.l.]
# 26  Grundriss von dem Meerbusen und Hafen Valparay...             [S.l.]
# 28  Plan sénographique (sic) de la cité des rois o...             [S.l.]
# 29  El puerto de El Callao, en el Mar Pacyfyco, od...             [S.l.]
# 31  Relacion historica del viage a la América meri...             Madrid
# 2   Relacion historica del viage a la America meri...      Unknown Place
# 6   Observaciones astronómicas y phísicas, hechas ...             Madrid
# 18  Dissertación histórica y geográphica sobre el ...          En Madrid
#
#    yearOfPublication                                   langCode  \
# 27              1744  http://id.loc.gov/vocabulary/iso639-2/fre
# 24              1744  http://id.loc.gov/vocabulary/iso639-2/spa
# 25              1744  http://id.loc.gov/vocabulary/iso639-2/ger
# 26              1744  http://id.loc.gov/vocabulary/iso639-2/ger
# 28              1744  http://id.loc.gov/vocabulary/iso639-2/fre
# 29              1744  http://id.loc.gov/vocabulary/iso639-2/spa
# 31              1748  http://id.loc.gov/vocabulary/iso639-2/spa
# 2               1748  http://id.loc.gov/vocabulary/iso639-2/spa
# 6               1748  http://id.loc.gov/vocabulary/iso639-2/spa
# 18              1749  http://id.loc.gov/vocabulary/iso639-2/spa
#
#                                        edition
# 27                    [S.l.] : [s.n.] , [1744]
# 24                   Matriti : [s.n.] , [1744]
# 25                    [S.l.] : [s.n.] , [1744]
# 26                    [S.l.] : [s.n.] , [1744]
# 28                    [S.l.] : [s.n.] , [1744]
# 29                      [S.l.] : [s.n.] , 1744
# 31                      Madrid : [s.n.] , 1748
# 2                                       , 1748
# 6                 Madrid : J. de Zúñiga , 1748
# 18  En Madrid : en la impr. de A. Marín , 1749
