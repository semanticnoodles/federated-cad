# %% [markdown]
# # Creating Collections as Data Using Federated Queries / BVMC Query Building (3)
# ## About the Notebook
# This notebook demonstrates how to use [SPARQL](https://www.w3.org/TR/sparql11-query/) to query Linked Open Data repositories. Specifically, it showcases how to perform federated queries by combining data from [Wikidata](https://www.wikidata.org) and the [Biblioteca Virtual Miguel de Cervantes (BVMC)](https://data.cervantesvirtual.com), which has published its catalog as Linked Open Data and makes use of [Resource, Description and Access (RDA)](http://www.rdaregistry.info/") as main vocabulary.
#
# <!--🔖 **How to Cite**: [![DOI](https://zenodo.org/badge/DOI_NUMBER.svg)](https://doi.org/DOI_NUMBER) fix once we get the CITATION.cff set up in the GitHub repo-->
#
# ---
#
# ## Getting Started
# First of all, we start by importing the `SPARQLWrapper` library, which is used to interact with SPARQL endpoints.
# Then, the SPARQL endpoint for Wikidata is set up, and JSON is the return format specified for our query.
#
# The <a href="https://data.cervantesvirtual.com"></a> published its catalogue as Linked Open data
#
# This example shows how to use <a href="https://www.w3.org/TR/sparql11-query/">SPARQL</a> as a query language in Linked Open Data repositories.

# %%
# Import necessary libraries
from SPARQLWrapper import SPARQLWrapper, JSON

# Set up the SPARQL endpoint for Wikidata
sparql = SPARQLWrapper("https://query.wikidata.org/sparql")
sparql.setReturnFormat(JSON)

# %% [markdown]
# ## Writing Our First SPARQL Query
#
# In this section, we construct a federated SPARQL query that begins by retrieving the BVMC identifier (`P2799`) for a specific Wikidata entity, in this case, the author Jorge Juan y Santacilia (`wd:Q2085725`). What makes this query federated is the use of the `SERVICE` keyword, which allows us to access the BVMC SPARQL endpoint and combine its data with Wikidata.
#
# Along with the RDA ontologies on use (`rdaw`, `rdam`, `rdae`), the  MADS/RDF ontology (`madsrdf`) is used to retrieve controlled vocabulary terms, such as language codes; last, the RDFS ontology (`rdfs`) is used to retrieve labels for resources, making the data more human-readable.

# %%
sparql.setQuery(
    """
PREFIX rdaw: <http://rdaregistry.info/Elements/w/>
PREFIX rdam: <http://rdaregistry.info/Elements/m/>
PREFIX rdae: <http://rdaregistry.info/Elements/e/>
PREFIX madsrdf: <http://www.loc.gov/mads/rdf/v1#>

SELECT ?author ?work ?workLabel ?placeOfProduction ?yearOfPublication ?langCode 
WHERE {
  wd:Q2085725 wdt:P2799 ?id .
  wd:Q2085725 rdfs:label ?author.  FILTER(LANG(?author) = "en").
  BIND(uri(concat("https://data.cervantesvirtual.com/person/", ?id)) as ?bvmcID)
  SERVICE <http://data.cervantesvirtual.com/openrdf-sesame/repositories/data> {
    # ?work rdaw:author ?bvmcID .
    # ?work rdfs:label ?workLabel .
    # ?work rdaw:manifestationOfWork ?manifestation .  
    # ?work rdaw:expressionOfWork ?expression .
    OPTIONAL {?expression rdae:languageOfExpression ?language . ?language madsrdf:code ?langCode .}
    OPTIONAL {?manifestation rdam:placeOfProduction ?placeOfProduction .}
    OPTIONAL {?manifestation rdam:dateOfPublication ?dateOfPublication . BIND(REPLACE(str(?dateOfPublication), "https://data.cervantesvirtual.com/date/", "", "i") AS ?yearOfPublication) .}
  }
}
LIMIT 1000
"""
)

# %% [markdown]
# ## Storing the Query Results and Creating a DataFrame
# In this section, we will create a dataframe from the results of our SPARQL query. We will use the `pandas` library to create a dataframe and populate it with the data retrieved from the BNF SPARQL endpoint.
#
# If there are missing values in the data, the code handles them by assigning empty strings (`""`) to the corresponding fields. This ensures that the `data` list contains consistent dictionaries, even when some fields are not available in the SPARQL query results.

# %%
try:
    ret = sparql.queryAndConvert()

    for r in ret["results"]["bindings"]:
        print('Author: ', r['author']['value'], ' Work: ', r['work']['value'], ' Title: ', r['workLabel']['value'], ' placeOfProduction: ', r['placeOfProduction']['value'],
             ' Year publication: ', r['yearOfPublication']['value'])
except Exception as e:
    print(e)

# %%
# Preview a limited number of results from the SPARQL query
try:
    ret = sparql.queryAndConvert()

    # Limit the number of results to preview
    preview_limit = 7
    # Check if the results contain any bindings
    if "bindings" not in ret["results"]:
        print("No results found.")
        exit(1)
    count = 0

    # Iterate through the results and print the desired fields
    for r in ret["results"]["bindings"]:
        if count >= preview_limit:
            break

        # Print only the most relevant fields
        print(f"Title: {r['workLabel']['value']}")
        print(f"Author: {r['author']['value']}")
        if "yearOfPublication" in r:
            print(f"Year: {r['yearOfPublication']['value']}")
        if "placeOfProduction" in r:
            print(f"Place: {r['placeOfProduction']['value']}")
        if "work" in r:
            print(f"Work: {r['work']['value']}")
        if "edition" in r:
            print(f"Edition: {r['edition']['value']}")
        if "langCode" in r:
            print(f"Language: {r['langCode']['value']}")

        print("---")
        count += 1

except Exception as e:
    print("Exception:")
    print(e)
# Out:
# Title: Examen maritimo theorico practico, o tratado de mechanica aplicado a la construccion, conocimiento y manejo de los navios y demas embarcaciones
# Author: Jorge Juan y Santacilia
# Year: 1771
# Place: en la Imprenta de D. Francisco Manuel de Mena, Calle de las Carretas, 1771
# Work: https://data.cervantesvirtual.com/work/662222
# Language: es
# ---
# Title: Elogio de D. Jorge Juan, Comendador de Aliaga en la Orden de S. Juan... [Texto impreso]
# Author: Jorge Juan y Santacilia
# Year: 1750
# Place: 1750
# Work: https://data.cervantesvirtual.com/work/666509
# Language: es
# ---
# Title: Estado de la astronomia en Europa [Texto impreso] : Y juicio de los fundamentos sobre que se erigieron los Systemas del Mundo, para que sirva de guia al mètodo en que debe recibirlos la Nación ...
# Author: Jorge Juan y Santacilia
# Year: 1774
# Place: en la Imprenta Real de la Gazeta, 1774
# Work: https://data.cervantesvirtual.com/work/666530
# Language: es
# ---
# Title: Observaciones astronomicas y physicas ... en los reynos del Peru [Texto impreso]
# Author: Jorge Juan y Santacilia
# Year: 1748
# Place: por Juan de Zuñiga, 1748
# Work: https://data.cervantesvirtual.com/work/666560
# Language: es
# ---
# Title: Método de levantar y dirigir el mapa o plano general de España
# Author: Jorge Juan y Santacilia
# Year: 1809
# Place: Madrid, en la Imprenta Real, 1809, pp. 143-151
# Work: https://data.cervantesvirtual.com/work/109096
# Language: es
# ---
# Title: Reflexiones sobre el Método de levantar el mapa general de España
# Author: Jorge Juan y Santacilia
# Year: 1809
# Place: Madrid, en la Imprenta Real, 1809, pp. 152-155
# Work: https://data.cervantesvirtual.com/work/109097
# Language: es
# ---
# Title: Carta de don Jorge Juan a don Sebastián Canterzani sobre las observaciones del paso de Venus por el disco del Sol
# Author: Jorge Juan y Santacilia
# Year: 1809
# Place: Madrid, en la Imprenta Real, 1809, pp. 160-163
# Work: https://data.cervantesvirtual.com/work/109098
# Language: es
# ---

# %% [markdown]
# ## Storing the Query Results and Creating a DataFrame
# In this section, we will create a dataframe from the results of our SPARQL query. We will use the `pandas` library to create a dataframe and populate it with the data retrieved from the BVMC SPARQL endpoint.
#
# If there are missing values in the data, the code handles them by assigning empty strings (`""`) to the corresponding fields. This ensures that the `data` list contains consistent dictionaries, even when some fields are not available in the SPARQL query results.

# %%
# Initialize an empty list to store the processed data
data = []

# Iterate through the results from the SPARQL query
for r in ret["results"]["bindings"]:
    data.append(
        {
            "author": r.get("author", {}).get("value", ""),
            "work": r.get("work", {}).get("value", ""),
            "title": r.get("workLabel", {}).get("value", ""),
            "langCode": r.get("langCode", {}).get("value", ""),
            "edition": r.get("edition", {}).get("value", ""),
            "yearOfPublication": r.get("yearOfPublication", {}).get("value", ""),
            "placeOfProduction": r.get("placeOfProduction", {}).get("value", ""),
        }
    )

# Print the first 15 items
data[0:15]
# Out:
# [{'author': 'Jorge Juan y Santacilia',
#   'work': 'https://data.cervantesvirtual.com/work/662222',
#   'title': 'Examen maritimo theorico practico, o tratado de mechanica aplicado a la construccion, conocimiento y manejo de los navios y demas embarcaciones',
#   'langCode': 'es',
#   'edition': '',
#   'yearOfPublication': '1771',
#   'placeOfProduction': 'en la Imprenta de D. Francisco Manuel de Mena, Calle de las Carretas, 1771'},
#  {'author': 'Jorge Juan y Santacilia',
#   'work': 'https://data.cervantesvirtual.com/work/666509',
#   'title': 'Elogio de D. Jorge Juan, Comendador de Aliaga en la Orden de S. Juan... [Texto impreso]',
#   'langCode': 'es',
#   'edition': '',
#   'yearOfPublication': '1750',
#   'placeOfProduction': '1750'},
#  {'author': 'Jorge Juan y Santacilia',
#   'work': 'https://data.cervantesvirtual.com/work/666530',
#   'title': 'Estado de la astronomia en Europa [Texto impreso] : Y juicio de los fundamentos sobre que se erigieron los Systemas del Mundo, para que sirva de guia al mètodo en que debe recibirlos la Nación ...',
#   'langCode': 'es',
#   'edition': '',
#   'yearOfPublication': '1774',
#   'placeOfProduction': 'en la Imprenta Real de la Gazeta, 1774'},
#  {'author': 'Jorge Juan y Santacilia',
#   'work': 'https://data.cervantesvirtual.com/work/666560',
#   'title': 'Observaciones astronomicas y physicas ... en los reynos del Peru [Texto impreso]',
#   'langCode': 'es',
#   'edition': '',
#   'yearOfPublication': '1748',
#   'placeOfProduction': 'por Juan de Zuñiga, 1748'},
#  {'author': 'Jorge Juan y Santacilia',
#   'work': 'https://data.cervantesvirtual.com/work/109096',
#   'title': 'Método de levantar y dirigir el mapa o plano general de España',
#   'langCode': 'es',
#   'edition': '',
#   'yearOfPublication': '1809',
#   'placeOfProduction': 'Madrid, en la Imprenta Real, 1809, pp. 143-151'},
#  {'author': 'Jorge Juan y Santacilia',
#   'work': 'https://data.cervantesvirtual.com/work/109097',
#   'title': 'Reflexiones sobre el Método de levantar el mapa general de España',
#   'langCode': 'es',
#   'edition': '',
#   'yearOfPublication': '1809',
#   'placeOfProduction': 'Madrid, en la Imprenta Real, 1809, pp. 152-155'},
#  {'author': 'Jorge Juan y Santacilia',
#   'work': 'https://data.cervantesvirtual.com/work/109098',
#   'title': 'Carta de don Jorge Juan a don Sebastián Canterzani sobre las observaciones del paso de Venus por el disco del Sol',
#   'langCode': 'es',
#   'edition': '',
#   'yearOfPublication': '1809',
#   'placeOfProduction': 'Madrid, en la Imprenta Real, 1809, pp. 160-163'},
#  {'author': 'Jorge Juan y Santacilia',
#   'work': 'https://data.cervantesvirtual.com/work/109099',
#   'title': 'Parecer de don Jorge Juan sobre el relox o cronómetro inventado por Juan Harrison',
#   'langCode': 'es',
#   'edition': '',
#   'yearOfPublication': '1809',
#   'placeOfProduction': 'Madrid, en la Imprenta Real, 1809, pp. 176-184'},
#  {'author': 'Jorge Juan y Santacilia',
#   'work': 'https://data.cervantesvirtual.com/work/109100',
#   'title': 'Reflexiones sobre la fábrica y uso del Cuarto-de-circulo',
#   'langCode': 'es',
#   'edition': '',
#   'yearOfPublication': '1809',
#   'placeOfProduction': 'Madrid, en la Imprenta Real, 1809, pp. 253-320'},
#  {'author': 'Jorge Juan y Santacilia',
#   'work': 'https://data.cervantesvirtual.com/work/97199',
#   'title': 'Compendio de navegación para el uso de los cavalleros Guardias Marinas',
#   'langCode': 'es',
#   'edition': '',
#   'yearOfPublication': '1757',
#   'placeOfProduction': 'España. Cádiz'},
#  {'author': 'Jorge Juan y Santacilia',
#   'work': 'https://data.cervantesvirtual.com/work/671248',
#   'title': 'Compendio de navegacion para el uso de los cavalleros guardias-marinas',
#   'langCode': 'es',
#   'edition': '',
#   'yearOfPublication': '1757',
#   'placeOfProduction': 'Cádiz : En la Academia de los mismos Cavalleros, 1757'},
#  {'author': 'Jorge Juan y Santacilia',
#   'work': 'https://data.cervantesvirtual.com/work/33992',
#   'title': 'Observaciones astronomicas y phisicas hechas de orden de S. M. en los Reynos del Peru',
#   'langCode': 'es',
#   'edition': '',
#   'yearOfPublication': '1773',
#   'placeOfProduction': 'Madrid, En la Imprenta Real de la Gazeta, 1773'},
#  {'author': 'Jorge Juan y Santacilia',
#   'work': 'https://data.cervantesvirtual.com/work/64368',
#   'title': 'Relacion historica del viage a la America Meridional hecho de orden de S. Mag. para medir algunos grados de meridiano terrestre y venir por ellos en conocimiento de la verdadera figura y magnitud de la tierra, con otras observaciones astronomicas y phisicas',
#   'langCode': 'es',
#   'edition': '',
#   'yearOfPublication': '1748',
#   'placeOfProduction': 'En Madrid : por Antonio Marin, 1748.'},
#  {'author': 'Jorge Juan y Santacilia',
#   'work': 'https://data.cervantesvirtual.com/work/64369',
#   'title': 'Relacion historica del viage a la America Meridional hecho de orden de S. Mag. para medir algunos grados de meridiano terrestre y venir por ellos en conocimiento de la verdadera figura y magnitud de la tierra, con otras observaciones astronomicas y phisicas',
#   'langCode': 'es',
#   'edition': '',
#   'yearOfPublication': '1748',
#   'placeOfProduction': 'En Madrid : por Antonio Marin, 1748.'},
#  {'author': 'Jorge Juan y Santacilia',
#   'work': 'https://data.cervantesvirtual.com/work/64370',
#   'title': 'Relacion historica del viage a la America Meridional hecho de orden de S. Mag. para medir algunos grados de meridiano terrestre y venir por ellos en conocimiento de la verdadera figura y magnitud de la tierra, con otras observaciones astronomicas y phisicas',
#   'langCode': 'es',
#   'edition': '',
#   'yearOfPublication': '1748',
#   'placeOfProduction': 'En Madrid : por Antonio Marin, 1748.'}]

# %% [markdown]
# To make this code more robust and handling missing data more efficiently, we can use `.get()` and providing default values for optional fields, e.g. "Unknown xyz". This would prevent errors and ensure that the data processing step works even when some fields are not available in the query results.

# %%
# Initialize an empty list to store the processed data
data = []

# Iterate through the results from the SPARQL query
for r in ret["results"]["bindings"]:
    # Use .get() to provide default values for optional fields
    author = r.get("author", {}).get("value", "")
    work = r.get("work", {}).get("value", "Unknown Work")
    title = r.get("workLabel", {}).get("value", "Unknown Title")
    placeOfProduction = r.get("placeOfProduction", {}).get("value", "Unknown Place")
    yearOfPublication = r.get("yearOfPublication", {}).get("value", "Unknown Year")
    langCode = r.get("langCode", {}).get("value", "Unknown Language")
    edition = r.get("edition", {}).get("value", "Unknown Edition")

    # Append a dictionary containing the extracted data to the list
    data.append(
        {
            "author": author,
            "work": work,
            "title": work,
            "placeOfProduction": placeOfProduction,
            "yearOfPublication": yearOfPublication,
            "langCode": langCode,
            "edition": edition,
        }
    )

# Print the first 15 lines of the dictionary to check the results
data[:15]
# Out:
# [{'author': 'Jorge Juan y Santacilia',
#   'work': 'https://data.cervantesvirtual.com/work/662222',
#   'title': 'https://data.cervantesvirtual.com/work/662222',
#   'placeOfProduction': 'en la Imprenta de D. Francisco Manuel de Mena, Calle de las Carretas, 1771',
#   'yearOfPublication': '1771',
#   'langCode': 'es',
#   'edition': 'Unknown Edition'},
#  {'author': 'Jorge Juan y Santacilia',
#   'work': 'https://data.cervantesvirtual.com/work/666509',
#   'title': 'https://data.cervantesvirtual.com/work/666509',
#   'placeOfProduction': '1750',
#   'yearOfPublication': '1750',
#   'langCode': 'es',
#   'edition': 'Unknown Edition'},
#  {'author': 'Jorge Juan y Santacilia',
#   'work': 'https://data.cervantesvirtual.com/work/666530',
#   'title': 'https://data.cervantesvirtual.com/work/666530',
#   'placeOfProduction': 'en la Imprenta Real de la Gazeta, 1774',
#   'yearOfPublication': '1774',
#   'langCode': 'es',
#   'edition': 'Unknown Edition'},
#  {'author': 'Jorge Juan y Santacilia',
#   'work': 'https://data.cervantesvirtual.com/work/666560',
#   'title': 'https://data.cervantesvirtual.com/work/666560',
#   'placeOfProduction': 'por Juan de Zuñiga, 1748',
#   'yearOfPublication': '1748',
#   'langCode': 'es',
#   'edition': 'Unknown Edition'},
#  {'author': 'Jorge Juan y Santacilia',
#   'work': 'https://data.cervantesvirtual.com/work/109096',
#   'title': 'https://data.cervantesvirtual.com/work/109096',
#   'placeOfProduction': 'Madrid, en la Imprenta Real, 1809, pp. 143-151',
#   'yearOfPublication': '1809',
#   'langCode': 'es',
#   'edition': 'Unknown Edition'},
#  {'author': 'Jorge Juan y Santacilia',
#   'work': 'https://data.cervantesvirtual.com/work/109097',
#   'title': 'https://data.cervantesvirtual.com/work/109097',
#   'placeOfProduction': 'Madrid, en la Imprenta Real, 1809, pp. 152-155',
#   'yearOfPublication': '1809',
#   'langCode': 'es',
#   'edition': 'Unknown Edition'},
#  {'author': 'Jorge Juan y Santacilia',
#   'work': 'https://data.cervantesvirtual.com/work/109098',
#   'title': 'https://data.cervantesvirtual.com/work/109098',
#   'placeOfProduction': 'Madrid, en la Imprenta Real, 1809, pp. 160-163',
#   'yearOfPublication': '1809',
#   'langCode': 'es',
#   'edition': 'Unknown Edition'},
#  {'author': 'Jorge Juan y Santacilia',
#   'work': 'https://data.cervantesvirtual.com/work/109099',
#   'title': 'https://data.cervantesvirtual.com/work/109099',
#   'placeOfProduction': 'Madrid, en la Imprenta Real, 1809, pp. 176-184',
#   'yearOfPublication': '1809',
#   'langCode': 'es',
#   'edition': 'Unknown Edition'},
#  {'author': 'Jorge Juan y Santacilia',
#   'work': 'https://data.cervantesvirtual.com/work/109100',
#   'title': 'https://data.cervantesvirtual.com/work/109100',
#   'placeOfProduction': 'Madrid, en la Imprenta Real, 1809, pp. 253-320',
#   'yearOfPublication': '1809',
#   'langCode': 'es',
#   'edition': 'Unknown Edition'},
#  {'author': 'Jorge Juan y Santacilia',
#   'work': 'https://data.cervantesvirtual.com/work/97199',
#   'title': 'https://data.cervantesvirtual.com/work/97199',
#   'placeOfProduction': 'España. Cádiz',
#   'yearOfPublication': '1757',
#   'langCode': 'es',
#   'edition': 'Unknown Edition'},
#  {'author': 'Jorge Juan y Santacilia',
#   'work': 'https://data.cervantesvirtual.com/work/671248',
#   'title': 'https://data.cervantesvirtual.com/work/671248',
#   'placeOfProduction': 'Cádiz : En la Academia de los mismos Cavalleros, 1757',
#   'yearOfPublication': '1757',
#   'langCode': 'es',
#   'edition': 'Unknown Edition'},
#  {'author': 'Jorge Juan y Santacilia',
#   'work': 'https://data.cervantesvirtual.com/work/33992',
#   'title': 'https://data.cervantesvirtual.com/work/33992',
#   'placeOfProduction': 'Madrid, En la Imprenta Real de la Gazeta, 1773',
#   'yearOfPublication': '1773',
#   'langCode': 'es',
#   'edition': 'Unknown Edition'},
#  {'author': 'Jorge Juan y Santacilia',
#   'work': 'https://data.cervantesvirtual.com/work/64368',
#   'title': 'https://data.cervantesvirtual.com/work/64368',
#   'placeOfProduction': 'En Madrid : por Antonio Marin, 1748.',
#   'yearOfPublication': '1748',
#   'langCode': 'es',
#   'edition': 'Unknown Edition'},
#  {'author': 'Jorge Juan y Santacilia',
#   'work': 'https://data.cervantesvirtual.com/work/64369',
#   'title': 'https://data.cervantesvirtual.com/work/64369',
#   'placeOfProduction': 'En Madrid : por Antonio Marin, 1748.',
#   'yearOfPublication': '1748',
#   'langCode': 'es',
#   'edition': 'Unknown Edition'},
#  {'author': 'Jorge Juan y Santacilia',
#   'work': 'https://data.cervantesvirtual.com/work/64370',
#   'title': 'https://data.cervantesvirtual.com/work/64370',
#   'placeOfProduction': 'En Madrid : por Antonio Marin, 1748.',
#   'yearOfPublication': '1748',
#   'langCode': 'es',
#   'edition': 'Unknown Edition'}]

# %% [markdown]
# Now  let's convert our dictionary into a pandas DataFrame. We will use the `pd.DataFrame()` function to create a DataFrame from the list of dictionaries. Each dictionary in the list will represent a row in the DataFrame, and the keys of the dictionaries will become the column names.

# %%
# Load required libraries
import pandas as pd

# Create a DataFrame from the list of dictionaries
df = pd.DataFrame(data)

# Preview the first 10 rows
df.head(10)
# Out:
#                     author                                           work  \
# 0  Jorge Juan y Santacilia  https://data.cervantesvirtual.com/work/662222
# 1  Jorge Juan y Santacilia  https://data.cervantesvirtual.com/work/666509
# 2  Jorge Juan y Santacilia  https://data.cervantesvirtual.com/work/666530
# 3  Jorge Juan y Santacilia  https://data.cervantesvirtual.com/work/666560
# 4  Jorge Juan y Santacilia  https://data.cervantesvirtual.com/work/109096
# 5  Jorge Juan y Santacilia  https://data.cervantesvirtual.com/work/109097
# 6  Jorge Juan y Santacilia  https://data.cervantesvirtual.com/work/109098
# 7  Jorge Juan y Santacilia  https://data.cervantesvirtual.com/work/109099
# 8  Jorge Juan y Santacilia  https://data.cervantesvirtual.com/work/109100
# 9  Jorge Juan y Santacilia   https://data.cervantesvirtual.com/work/97199
#
#                                            title  \
# 0  https://data.cervantesvirtual.com/work/662222
# 1  https://data.cervantesvirtual.com/work/666509
# 2  https://data.cervantesvirtual.com/work/666530
# 3  https://data.cervantesvirtual.com/work/666560
# 4  https://data.cervantesvirtual.com/work/109096
# 5  https://data.cervantesvirtual.com/work/109097
# 6  https://data.cervantesvirtual.com/work/109098
# 7  https://data.cervantesvirtual.com/work/109099
# 8  https://data.cervantesvirtual.com/work/109100
# 9   https://data.cervantesvirtual.com/work/97199
#
#                                    placeOfProduction yearOfPublication  \
# 0  en la Imprenta de D. Francisco Manuel de Mena,...              1771
# 1                                               1750              1750
# 2             en la Imprenta Real de la Gazeta, 1774              1774
# 3                           por Juan de Zuñiga, 1748              1748
# 4     Madrid, en la Imprenta Real, 1809, pp. 143-151              1809
# 5     Madrid, en la Imprenta Real, 1809, pp. 152-155              1809
# 6     Madrid, en la Imprenta Real, 1809, pp. 160-163              1809
# 7     Madrid, en la Imprenta Real, 1809, pp. 176-184              1809
# 8     Madrid, en la Imprenta Real, 1809, pp. 253-320              1809
# 9                                      España. Cádiz              1757
#
#   langCode          edition
# 0       es  Unknown Edition
# 1       es  Unknown Edition
# 2       es  Unknown Edition
# 3       es  Unknown Edition
# 4       es  Unknown Edition
# 5       es  Unknown Edition
# 6       es  Unknown Edition
# 7       es  Unknown Edition
# 8       es  Unknown Edition
# 9       es  Unknown Edition

# %%
# Some basic statistics about the DataFrame
df.describe()
# Out:
#                          author  \
# count                        38
# unique                        1
# top     Jorge Juan y Santacilia
# freq                         38
#
#                                                  work  \
# count                                              38
# unique                                             38
# top     https://data.cervantesvirtual.com/work/662222
# freq                                                1
#
#                                                 title  \
# count                                              38
# unique                                             38
# top     https://data.cervantesvirtual.com/work/662222
# freq                                                1
#
#                            placeOfProduction yearOfPublication langCode  \
# count                                     38                38       38
# unique                                    30                12        2
# top     En Madrid : por Antonio Marin, 1748.              1748       es
# freq                                       5                 7       35
#
#                 edition
# count                38
# unique                1
# top     Unknown Edition
# freq                 38

# %%
# Checking extant data types
df.dtypes
# Out:
# author               object
# work                 object
# title                object
# placeOfProduction    object
# yearOfPublication    object
# langCode             object
# edition              object
# dtype: object

# %%
# Sort the DataFrame by yearOfPublication
sorted_df = df.sort_values(by="yearOfPublication")

# Preview the first 10 rows
sorted_df.head(10)
# Out:
#                      author                                            work  \
# 19  Jorge Juan y Santacilia   https://data.cervantesvirtual.com/work/136736
# 3   Jorge Juan y Santacilia   https://data.cervantesvirtual.com/work/666560
# 15  Jorge Juan y Santacilia    https://data.cervantesvirtual.com/work/64371
# 14  Jorge Juan y Santacilia    https://data.cervantesvirtual.com/work/64370
# 13  Jorge Juan y Santacilia    https://data.cervantesvirtual.com/work/64369
# 12  Jorge Juan y Santacilia    https://data.cervantesvirtual.com/work/64368
# 27  Jorge Juan y Santacilia    https://data.cervantesvirtual.com/work/42393
# 18  Jorge Juan y Santacilia   https://data.cervantesvirtual.com/work/108123
# 16  Jorge Juan y Santacilia    https://data.cervantesvirtual.com/work/64383
# 26  Jorge Juan y Santacilia  https://data.cervantesvirtual.com/work/1004811
#
#                                              title  \
# 19   https://data.cervantesvirtual.com/work/136736
# 3    https://data.cervantesvirtual.com/work/666560
# 15    https://data.cervantesvirtual.com/work/64371
# 14    https://data.cervantesvirtual.com/work/64370
# 13    https://data.cervantesvirtual.com/work/64369
# 12    https://data.cervantesvirtual.com/work/64368
# 27    https://data.cervantesvirtual.com/work/42393
# 18   https://data.cervantesvirtual.com/work/108123
# 16    https://data.cervantesvirtual.com/work/64383
# 26  https://data.cervantesvirtual.com/work/1004811
#
#                                     placeOfProduction yearOfPublication  \
# 19               En Madrid : por Antonio Marin, 1748.              1748
# 3                            por Juan de Zuñiga, 1748              1748
# 15               En Madrid : por Antonio Marin, 1748.              1748
# 14               En Madrid : por Antonio Marin, 1748.              1748
# 13               En Madrid : por Antonio Marin, 1748.              1748
# 12               En Madrid : por Antonio Marin, 1748.              1748
# 27               En Madrid : por Juan de Zuñiga, 1748              1748
# 18  En Madrid : en la Imprenta de Antonio Marin, 1749              1749
# 16  En Madrid : en la imprenta de Antonio Marin, 1...              1749
# 26  En Madrid : en la Imprenta de Antonio Marin, 1749              1749
#
#    langCode          edition
# 19       es  Unknown Edition
# 3        es  Unknown Edition
# 15       es  Unknown Edition
# 14       es  Unknown Edition
# 13       es  Unknown Edition
# 12       es  Unknown Edition
# 27       es  Unknown Edition
# 18       es  Unknown Edition
# 16       es  Unknown Edition
# 26       es  Unknown Edition
